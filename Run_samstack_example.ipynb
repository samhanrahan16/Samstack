# %%
from sams_stacking import samstack

# %% [markdown]
# # Single Mass Bin

# %%
# Path to the parameter file
params = '/home/sam/Desktop/LSB/samstack-master/Sams_parameters_example.cfg'
save_path_stacks = '/home/sam/Desktop/LSB/data/samstack_output/stacked_fluxes'
save_path_images = '/home/sam/Desktop/LSB/data/samstack_output/stacked_images'

# %%
stacker = samstack(params)
# Out:
# /home/sam/.local/lib/python2.7/site-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
stacker.save_stacked_fluxes(save_path_stacks)
# Out:
# stacking sample_2 spire_psw
# sams_stacking.py:110: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ngals_per_pix_all[name] == 'empty':

# %%
stacker.plot_the_stacked_fluxes(save_path_stacks)
# Out:
# stacking sample_2 spire_psw

# %%
# Number is the number of dimensions of the image
stacker.plot_the_stacked_images(9,save_path_images)
# Out:
# stacking sample_2 spire_psw

# %% [markdown]
# # Binned by Mass

# %%
params_binned = '/home/sam/Desktop/LSB/samstack-master/Sams_parameters_example_binned.cfg'

# %%
stacker_binned = samstack(params_binned)

# %%
stacker_binned.plot_the_stacked_fluxes(save_path_stacks)
# Out:
# stacking sample_2 spire_psw
